# %%
# !pip install colab_ssh --upgrade

# %%
from colab_ssh import launch_ssh_cloudflared

# ตั้งรหัสผ่าน SSH ตามที่ต้องการ
password = "1234x"

# สตาร์ท SSH + Cloudflare tunnel
launch_ssh_cloudflared(password=password)
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %% [markdown]
# Host *.trycloudflare.com
# 	HostName %h
# 	User root
# 	Port 22
# 	ProxyCommand <PUT_THE_ABSOLUTE_CLOUDFLARE_PATH_HERE> access ssh --hostname %h

# %%
print("Connect to your Colab instance using the SSH")
# Out:
# Connect to your Colab instance using the SSH

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# เลือกโมเดล pose (เร็ว ๆ ใช้ nano)
model = YOLO("yolo11n-pose.pt")  # หรือ "yolov8n-pose.pt"

# track จากกล้องเว็บแคม (source=0)
model.track(
    source=0,          # 0 = webcam, หรือใส่ path วิดีโอ
    show=True,         # แสดงหน้าต่างภาพพร้อมกระดูกและ track ID
    conf=0.4,          # confidence threshold
    iou=0.5,           # IoU สำหรับ tracking
    persist=True,      # ให้รักษา track ID ข้ามเฟรม
    verbose=False
)
